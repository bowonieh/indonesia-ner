# %%
import spacy
import pickle
import random
from spacy.util import minibatch, compounding
from spacy import load, displacy
#Load blank

# %%
with open('ner_spacy_fmt_datasets.pickle', 'rb') as f:
    ner_spacy_fmt_datasets = pickle.load(f)

# %%
#tambah Pipe
nlp = spacy.blank("id")
#nlp.add_pipe(nlp.create_pipe('ner'))
nlp.add_pipe('ner')
nlp.begin_training
# Out:
# <bound method Language.begin_training of <spacy.lang.id.Indonesian object at 0x000001B615D9DF70>>

# %%
import random
from spacy.util import minibatch, compounding

# %%
print(ner_spacy_fmt_datasets)
# Out:
# [('Pengamat politik dari Universitas Gadjah Mada Arie Sudjito menilai, keinginan Ketua Umum Partai Golkar Aburizal Bakrie untuk maju kembali sebagai ketua umum merupakan pemaksaan kehendak.', {'entities': [(22, 45, 'ORGANIZATION'), (46, 58, 'PERSON'), (89, 102, 'ORGANIZATION'), (103, 118, 'PERSON')]}), ('Menurut dia, ada kesan bahwa Aburizal menggunakan segala cara untuk memuluskan jalannya kembali menduduki Golkar 1.', {'entities': [(29, 37, 'PERSON'), (106, 112, 'ORGANIZATION')]}), ('Hal ini, kata Arie berpotensi menimbukan perpecahan di kalangan kader Golkar di daerah.', {'entities': [(14, 18, 'PERSON'), (70, 76, 'PERSON')]}), ('"Tentu ini akan merugikan Golkar karena Golkar akan pecah dan konflik di daerah dipastikan akan terjadi," ujar Arie saat dihubungi Kompas.com, Selasa (2/12/2014)', {'entities': [(26, 32, 'ORGANIZATION'), (40, 46, 'ORGANIZATION'), (111, 115, 'PERSON')]}), ('Arie mengatakan, sikap Aburizal tersebut ditentang oleh sebagian kalangan di internal Golkar yang melakukan perlawanan dengan membentuk Presidium Penyelamat Partai Golkar', {'entities': [(0, 4, 'PERSON'), (23, 31, 'PERSON'), (86, 92, 'ORGANIZATION')]}), ('Selain itu, dua calon ketua umum menyatakan mundur dan tak akan mencalonkan diri.', {'entities': []}), ('Mereka adalah MS Hidayat dan Airlangga Hartarto', {'entities': [(14, 24, 'PERSON')]}), ('Hidayat dan Airlangga mundur karena menganggap ada proses yang tidak demokratis dan tidak fair dalam Munas IX yang berlangsung di Bali', {'entities': [(0, 7, 'PERSON'), (12, 21, 'PERSON')]}), ('"Upaya Airlangga serius bertarung, tapi melihat gelagat tidak sehat, maka lebih baik mundur. Itu pun jalan moderat," kata Arie', {'entities': [(7, 16, 'PERSON')]}), ('Dengan mundurnya Hidayat dan Airlangga Aburizal berpotensi menjadi calon tunggal ketua umum yang akan dipilih dalam Munas IX.', {'entities': [(17, 24, 'PERSON'), (29, 38, 'PERSON'), (39, 47, 'PERSON')]}), ('Menurut Arie jika Aburizal terus memaksakan kehendaknya, bukan tidak mungkin Golkar akan menyusul Partai Persatuan Pembangunan yang terpecah karena konflik internal.', {'entities': [(8, 12, 'PERSON'), (18, 26, 'PERSON'), (77, 83, 'ORGANIZATION'), (98, 126, 'ORGANIZATION')]}), ('Arie mengatakan, para petinggi partai segera melakukan langkah-langkah untuk menyelamatkan partai berlambang pohon beringin tersebut.', {'entities': [(0, 4, 'PERSON')]}), ('"Ini indikasi atau tanda-tanda kebangkrutan Golkar kata Arie', {'entities': [(44, 50, 'ORGANIZATION')]}), ('Wakil Ketua DPR Fadli Zon mengkritik pemerintahan Joko Widodo yang dinilainya lambat dalam melakukan eksekusi terhadap para terpidana mati kasus narkoba.', {'entities': [(12, 15, 'ORGANIZATION'), (16, 25, 'PERSON'), (50, 61, 'PERSON')]}), ('Menurut Fadli semakin cepat eksekusi dilakukan, hal itu akan semakin baik.', {'entities': [(8, 13, 'PERSON')]}), ('"Pemerintah lambat, eksekusi lambat, eksekusi kapan tidak jelas karena lambatnya pemerintah mengambil keputusan," kata Fadil Zon di Gedung DPR, Senayan, Jakarta Rabu (11/3/2015)', {'entities': [(119, 128, 'PERSON'), (132, 160, 'LOCATION')]}), ('Menurut dia, karena lambatnya eksekusi mati ini, akhirnya terjadi perlawanan dari berbagai pihak, termasuk para terpidana.', {'entities': []}), ('Terpidana mati kasus narkoba yang merupakan warga negara Perancis Serge Atlaoui mengajukan upaya hukum lanjutan berupa peninjauan kembali ke Pengadilan Negeri Tangerang', {'entities': [(57, 65, 'LOCATION'), (66, 79, 'PERSON')]}), ('Sebelumnya, terpidana mati asal Filipina Mary Jane Fiesta Veloso juga telah mengajukan langkah serupa.', {'entities': [(32, 40, 'LOCATION'), (41, 64, 'PERSON')]}), ('"Ini membuat segala macam ekses terjadi. Pemerintah harusnya bisa mengambil sikap dengan cepat," ucap politisi Partai Gerindra itu.', {'entities': [(111, 126, 'ORGANIZATION')]}), ('Selain perlawanan dari terpidana, menurut Fadli Indonesia juga akan terus mendapatkan tekanan dari dunia internasional jika eksekusi mati terus ditunda.', {'entities': [(42, 47, 'PERSON'), (48, 57, ' ...

# %%
ner=nlp.get_pipe("ner")

# %%
for _, annotations in ner_spacy_fmt_datasets:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])
        break

# %%
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
unaffected_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# %%
print(nlp.pipe_names)
# Out:
# ['ner']

# %%
# TRAINING THE MODEL
with nlp.disable_pipes(*unaffected_pipes):

  # Training for 30 iterations
  for iteration in range(30):

    # shuufling examples  before every iteration
    random.shuffle(ner_spacy_fmt_datasets)
    losses = {}
    # batch up the examples using spaCy's minibatch
    batches = minibatch(ner_spacy_fmt_datasets, size=compounding(4.0, 32.0, 1.001))
    for batch in batches:
        texts, annotations = zip(*batch)
        print(texts)
        nlp.update(batch)
        ##            texts,  # batch of texts
          #          annotations,  # batch of annotations
           #         drop=0.5,  # dropout - make it harder to memorise data
           #         losses=losses,
           #     )
    
    print("Losses at iteration {}".format(iteration), losses)
#print(batches)
# Out:
# ('Sementara itu Pengamat Pasar Modal Dandossi Matram mengatakan, sulit bagi sebuah kantor akuntan publik untuk dapat menyelesaikan audit perusahaan sebesar Telkom dalam waktu 3 bulan.', 'Sementara itu Pengamat Pasar Modal Dandossi Matram mengatakan, sulit bagi sebuah kantor akuntan publik untuk dapat menyelesaikan audit perusahaan sebesar Telkom dalam waktu 3 bulan.', 'Makanya juga sekarang dibatasi kuota menjadi 46 juta KL dikurangi dari 48 juta KL , " kata Jero .', 'Prasetyo tak sepenuhnya politikus.', "(Baca: Perpu Pilkada, 'Tak Ada Koalisi Permalukan SBY' ) Musababnya, pemilihan secara langsung merupakan kehendak rakyat.", 'Sementara itu Pengamat Pasar Modal Dandossi Matram mengatakan, sulit bagi sebuah kantor akuntan publik untuk dapat menyelesaikan audit perusahaan sebesar Telkom dalam waktu 3 bulan.', 'Hanung juga menjamin tak ada penimbunan BBM terkait kondisi pembatasan jatah BBM subsidi di berbagai SPBU .', 'Pada 30 Juni , sebagian besar dari defisit perdagangan kita menurun !')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27940\4229274934.py in <module>
#      13         texts, annotations = zip(*batch)
#      14         print(texts)
# ---> 15         nlp.update(batch)
#      16         ##            texts,  # batch of texts
#      17           #          annotations,  # batch of annotations
#
# ~\anaconda3\lib\site-packages\spacy\language.py in update(self, examples, _, drop, sgd, losses, component_cfg, exclude, annotates)
#    1136         if isinstance(examples, list) and len(examples) == 0:
#    1137             return losses
# -> 1138         validate_examples(examples, "Language.update")
#    1139         examples = _copy_examples(examples)
#    1140         if sgd is None:
#
# ~\anaconda3\lib\site-packages\spacy\training\example.pyx in spacy.training.example.validate_examples()
#
# TypeError: [E978] The Language.update method takes a list of Example objects, but got: {<class 'tuple'>}

# %%
# Out:
#   File "<tokenize>", line 11
#     print("Losses at iteration {}".format(iteration), losses)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
DATA = new_spacy_fmt_datasets
contoh = []
for text, annots in DATA:
    contoh.append(DATA.from_dict(nlp.make_doc(text), annots))
nlp.initialize(lambda: examples)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6168\254974103.py in <module>
# ----> 1 DATA = new_spacy_fmt_datasets
#       2 contoh = []
#       3 for text, annots in DATA:
#       4     contoh.append(DATA.from_dict(nlp.make_doc(text), annots))
#       5 nlp.initialize(lambda: examples)
#
# NameError: name 'new_spacy_fmt_datasets' is not defined

# %%
for i in range(20):
    random.shuffle(contoh)
    for batch in minibatch(contoh, size=8):
        nlp.update(batch)
